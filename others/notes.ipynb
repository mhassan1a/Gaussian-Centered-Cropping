# %%
import requests

pic_url = 'https://images.pexels.com/photos/1108099/pexels-photo-1108099.jpeg?auto=compress&cs=tinysrgb&w=600'

with open('pic1.jpg', 'wb') as handle:
    response = requests.get(pic_url, stream=True)

    if not response.ok:
        print(response)

    for block in response.iter_content(1024):
        if not block:
            break

        handle.write(block)

# %%
from datetime import datetime
import json

results = {}
results['epoch'] = 1
results['num_classes_workers'] = 2
results['hidden_dim'] = 0
results['batch_size'] = 2
date = datetime.now()
# with open(f'results_{date}_.json', 'w') as f:
#     json.dump(results, f)

# %%
def tikzplotlib_fix_ncols(obj):
    """
    workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
    """
    if hasattr(obj, "_ncols"):
        obj._ncol = obj._ncols
    for child in obj.get_children():
        tikzplotlib_fix_ncols(child)

# %%
import pandas as pd
import numpy as np
#data = {'GCC_NO_regularization': {0.4: {0.001: [(0.2728, 0.2727, 0.21605)], 0.01: [(0.2606, 0.2368, 0.2218)], 0.1: [(0.2449, 0.2466, 0.216)], 0.3: [(0.2338, 0.2305, 0.2084)], 0.5: [(0.2562, 0.2624, 0.2146)], 0.7: [(0.2648, 0.264, 0.214775)], 1: [(0.2593, 0.2697, 0.220875)], 2: [(0.2353, 0.2425, 0.21545)], 5: [(0.2569, 0.2481, 0.21235)], 10: [(0.2597, 0.2635, 0.207325)], 100: [(0.2618, 0.2542, 0.21285)], 200: [(0.2667, 0.2596, 0.2247)]}, 0.6: {0.001: [(0.2312, 0.2555, 0.22645)], 0.01: [(0.2432, 0.2564, 0.218375)], 0.1: [(0.2378, 0.2551, 0.221475)], 0.3: [(0.261, 0.2482, 0.216225)], 0.5: [(0.2107, 0.2193, 0.211)], 0.7: [(0.2555, 0.2469, 0.20945)], 1: [(0.2857, 0.2693, 0.22245)], 2: [(0.2506, 0.2424, 0.2071)], 5: [(0.2358, 0.2312, 0.210975)], 10: [(0.2657, 0.2769, 0.22075)], 100: [(0.2183, 0.2294, 0.2074)], 200: [(0.2774, 0.2734, 0.220775)]}, 0.8: {0.001: [(0.2149, 0.2228, 0.20375)], 0.01: [(0.2423, 0.2479, 0.21785)], 0.1: [(0.2428, 0.251, 0.208625)], 0.3: [(0.2674, 0.2515, 0.214625)], 0.5: [(0.259, 0.2597, 0.221425)], 0.7: [(0.2632, 0.2635, 0.211175)], 1: [(0.2516, 0.2571, 0.2068)], 2: [(0.2698, 0.2685, 0.219825)], 5: [(0.2251, 0.2442, 0.2104)], 10: [(0.2594, 0.2654, 0.21255)], 100: [(0.2585, 0.2648, 0.2128)], 200: [(0.2655, 0.2679, 0.231275)]}}}

# Convert data into a list of dictionaries
data = {"results": {"GCC_NO_regularization": {"0.4": {"0.001": [[0.3964, 0.3879, 0.370725], [0.4017, 0.3885, 0.37185], [0.4052, 0.3857, 0.370325], [0.3965, 0.386, 0.368825]], "0.01": [[0.394, 0.3885, 0.37905], [0.3879, 0.3733, 0.375075], [0.4007, 0.3907, 0.378675], [0.389, 0.3857, 0.377175]], "0.1": [[0.4224, 0.4148, 0.39505], [0.4137, 0.4127, 0.39845], [0.4093, 0.4131, 0.392875], [0.4124, 0.4076
.3947, 0.3816], [0.3922, 0.3926, 0.381225], [0.3877, 0.3897, 0.384825], [0.3912, 0.3933, 0.3842]], "0.5": [[0.3932, 0.3932, 0.382875], [0.3952, 0.3931, 0.385425], [0.401, 0.3973, 0.385225], [0.398, 0.3972, 0.386175]], "0.7": [[0.3917, 0.391, 0.381225], [0.3882, 0.3879, 0.38325], [0.3953, 0.3936, 0.3805], [0.3945, 0.3881, 0.38115]], "1": [[0.3998, 0.3906, 0.3781], [0.3951, 0.3911, 0.382275], [0.3896, 0.39, 0.378325], [0.3962, 0.3911, 0.379225]], "2": [[0.3922, 0.3871, 0.384075], [0.3916, 0.3941, 0.3846], [0.3926, 0.3866, 0.38225], [0.3973, 0.3901, 0.381525]], "5": [[0.3955, 0.3928, 0.383325], [0.3943, 0.3925, 0.384125], [0.3981, 0.3955, 0.38525], [0.3959, 0.3928, 0.385625]], "10": [[0.4, 0.3993, 0.384775], [0.3921, 0.3925, 0.3846], [0.3936, 0.3881, 0.3835], [0.4002, 0.3954, 0.383575]], "100": [[0.4033, 0.3942, 0.390125], [0.4008, 0.3937, 0.3873], [0.4072, 0.3965, 0.38665], [0.4052, 0.3931, 0.387525]], "200": [[0.4027, 0.3974, 0.38435], [0.4079, 0.3998, 0.39035], [0.4002, 0.3912, 0.387], [0.4105, 0.3988, 0.38875]]}}}, "epoch": 2, "num_classes_workers": 3, "hidden_dim": 256, "batch_size": 512}

rows = []


for cropsize, cropsize_data in data['results']['GCC_NO_regularization'].items():
    for std, t in cropsize_data.items():
        test = [t[i][0] for i in range(len(t))]
        train = [t[i][2] for i in range(len(t))]
        val = [t[i][1] for i in range(len(t))]
        
        rows.append({'Method': 'GCC_NO_regularization',
                     'Cropsize': cropsize,
                     'Std': std,
                     'test_mean': np.mean(test),
                     'train_mean': np.mean(train), 
                     'val_mean': np.mean(val), 
                     'test_cer': np.std(test, ddof=1),
                     'train_cer': np.std(train, ddof=1), 
                     'val_cer': np.std(val, ddof=1),
                    })

# Create DataFrame
df = pd.DataFrame(rows)
#df['mean'] = df[['t1','t2','t3','t4']].mean(axis=1)
#df['certainty bound'] = df[['t1','t2','t3']].std(axis=1)
print(df.head(5))
# Out:
#                   Method Cropsize    Std  test_mean  train_mean  val_mean  \
# 0  GCC_NO_regularization      0.4  0.001   0.399950    0.370431  0.387025
# 1  GCC_NO_regularization      0.4   0.01   0.392900    0.377494  0.384550
# 2  GCC_NO_regularization      0.4    0.1   0.414450    0.393700  0.412050
# 3  GCC_NO_regularization      0.4    0.3   0.415975    0.404969  0.421325
# 4  GCC_NO_regularization      0.4    0.5   0.424500    0.411806  0.426925
#
#    test_cer  train_cer   val_cer
# 0  0.004287   0.001250  0.001384
# 1  0.005838   0.001805  0.007774
# 2  0.005612   0.004199  0.003103
# 3  0.002923   0.001678  0.004324
# 4  0.003400   0.002067  0.002939

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker

# Get unique crop sizes
unique_crop_sizes = df['Cropsize'].unique()
act_crop_sizes=  [20, 24, 28]
act_crop_sizes = map(lambda x: round(x*x/(32*32)*100,1), act_crop_sizes)
act_crop_sizes = list(act_crop_sizes)
print(act_crop_sizes)
# Iterate over crop sizes and create a figure for each
for i, crop_size in enumerate(unique_crop_sizes):
    # Filter DataFrame for the current crop size
    crop_size_df = df[df['Cropsize'] == crop_size]
    
    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(crop_size_df['Std'], crop_size_df['test_mean'], c='red', alpha=1, label='Mean', )
    plt.fill_between(crop_size_df['Std'], crop_size_df['test_mean'] - crop_size_df['test_cer'],
                     crop_size_df['test_mean'] + crop_size_df['test_cer'], color='blue', alpha=0.3, label='+/-')
    plt.ylim(0, 1)
    #plt.ticklabel_format(axis='x', style='sci', scilimits=(0,0))
    plt.title(f'GCC with Crop Size {act_crop_sizes[i]:}%')
    plt.ylabel('Mean Test accuracy')
    plt.xlabel('Variance')
    plt.grid()
    obj = plt.legend()
    tikzplotlib_fix_ncols(obj)
    import tikzplotlib
    tikzplotlib.save(f'figures/cropsize_{crop_size}_figure.tex')  # Save figure with a unique name and ".tex" extension
# Out:
# [39.1, 56.2, 76.6]

# %% [markdown]
# # RANDOM CROP

# %%
import pandas as pd
import numpy as np

# Convert data into a list of dictionaries
data = {"results": {"Random_crop_pytorch": {"20": {"0.001": [[0.5966, 0.5991, 0.643325], [0.5972, 0.602, 0.6454], [0.5879, 0.5915, 0.6436], [0.5886, 0.5978, 0.639625], [0.5934, 0.595, 0.643425]]}, "24": {"0.001": [[0.5516, 0.5643, 0.617175], [0.5461, 0.5594, 0.61185], [0.545, 0.5619, 0.60785], [0.5448, 0.5606, 0.61045], [0.5443, 0.5556, 0.6161]]}, "28": {"0.001": [[0.496, 0.4985, 0.547125], [0.4948, 0.4971, 0.549225], [0.5013, 0.5014, 0.5512], [0.4948, 0.497, 0.548325], [0.4944, 0.4923, 0.541175]]}}}, "epoch": 150, "num_classes_workers": 3, "hidden_dim": 256, "batch_size": 512}
rows = []


for cropsize, cropsize_data in data['results']['Random_crop_pytorch'].items():
    for std, t in cropsize_data.items():
        test = [t[i][0] for i in range(len(t))]
        train = [t[i][2] for i in range(len(t))]
        val = [t[i][1] for i in range(len(t))]
        
        rows.append({'Method': 'Random_crop_pytorch',
                     'Cropsize': cropsize,
                     'Std': std,
                     'test_mean': np.mean(test),
                     'train_mean': np.mean(train), 
                     'val_mean': np.mean(val), 
                     'test_cer': np.std(test, ddof=1),
                     'train_cer': np.std(train, ddof=1), 
                     'val_cer': np.std(val, ddof=1),
                    })

df = pd.DataFrame(rows)
df['Cropsize'] = df['Cropsize'].astype(int).apply(lambda x: round(x*x/(32*32)*100,1))
#print(df.head(5))
plt.scatter(df['Cropsize'].astype(str), df['test_mean'], c='red', alpha=1, label='Mean',)
plt.title('Random Crop Pytorch')
# plt.fill_between(df['Cropsize'], df['test_mean'] - df['test_cer'], 
#                  df['test_mean']+ df['test_cer'], color='blue',
#                  alpha=0.3, label='+/-')
plt.xlabel('% Cropsize')
plt.ylabel('Mean Test accuracy')
plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.grid()
obj = plt.legend()

plt.savefig('figures/Random_crop_pytorch.png')
tikzplotlib_fix_ncols(obj)
import tikzplotlib
tikzplotlib.save('figures/Random_crop_pytorch.tex')
